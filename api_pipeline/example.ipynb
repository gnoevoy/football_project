# %%
import pandas as pd
import numpy as np
import json

# %%
path = r"/home/bars1k/football_project/api_pipeline/api-pipeline_raw_boots.json"
with open(path, 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data["products"])
df.head()
# Out:
#    product_id                        created_at  \
# 0           1  2025-04-10T21:36:41.167902+02:00
# 1           2  2025-04-10T21:36:41.167902+02:00
# 2           3  2025-04-10T21:36:41.167902+02:00
# 3           4  2025-04-10T21:36:41.167902+02:00
# 4           5  2025-04-10T21:36:41.167902+02:00
#
#                                                title   price  old_price  \
# 0                   Cleats Adidas F50 Elite Fg - Red  208.99     260.00
# 1  Cleats Nike Zoom Mercurial Vapor 16 Elite Nu1 ...  279.99        NaN
# 2                  Adidas Mundial Team Boots - Black  107.99     150.00
# 3  Cleats Nike Zoom Mercurial Vapor 16 Elite Fg -...  269.99        NaN
# 4        Cleats Nike Phantom Luna Ii Elite Fg - Blue  168.99     279.99
#
#                                          description  avg_vote_rate  \
# 0  Unlock speed with adidas F50. Designed for max...            4.4
# 1                                               None            5.0
# ...
