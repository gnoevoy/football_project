# %%
import pandas as pd
import numpy as np
import json

# %%
path = r"/home/bars1k/football_project/api_pipeline/api-pipeline_raw_balls.json"

with open(path, 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data["products"])
df.head()
# Out:
#    product_id                        created_at  \
# 0         514  2025-04-10T21:36:41.167902+02:00
# 1         515  2025-04-10T21:36:41.167902+02:00
# 2         516  2025-04-10T21:36:41.167902+02:00
# 3         517  2025-04-10T21:36:41.167902+02:00
# 4         518  2025-04-10T21:36:41.167902+02:00
#
#                                                title   price  old_price  \
# 0                        Ball Adidas Tiro Pro Size 5   64.99     100.00
# 1  Ball Adidas Uefa Nations League 2024 Pro Size ...   97.99     150.00
# 2  Ball Select Brillant Super Tb Fifa V24 Betclic...   93.99     122.99
# 3                   Ball Adidas Ucl Pro 24/25 Size 5  150.00        NaN
# 4          Ball Adidas Uwcl Pro 24/25 Size 5 - White  150.00        NaN
#
#                                          description  avg_vote_rate  \
# 0  The best teams need the best match balls. And ...            4.9
# 1  A bow towards full passion support. The colorf...            5.0
# ...
