# %%
import pandas as pd
import numpy as np
import ast
import json

# %%
file = r"/home/bars1k/football_project/data.csv"
df = pd.read_csv(file)
df.head(3)
# Out:
#    product_id                        created_at  \
# 0           1  2025-04-10T21:36:41.167902+02:00
# 1           2  2025-04-10T21:36:41.167902+02:00
# 2           3  2025-04-10T21:36:41.167902+02:00
#
#                                                title   price  old_price  \
# 0                   Cleats Adidas F50 Elite Fg - Red  208.99      260.0
# 1  Cleats Nike Zoom Mercurial Vapor 16 Elite Nu1 ...  279.99        NaN
# 2                  Adidas Mundial Team Boots - Black  107.99      150.0
#
#                                          description  avg_vote_rate  \
# 0  Unlock speed with adidas F50. Designed for max...            4.4
# 1                                                NaN            5.0
# 2  This is probably one of the most popular shoe ...            4.9
#
#    num_votes           labels  \
# 0        9.0               []
# 1       22.0  ['Last Chance']
# 2      826.0               []
#
# ...

# %%
products_cols = ["product_id", "created_at", "title", "price", "old_price", "description", "avg_vote_rate", "num_votes", "category_id"]
products = df[products_cols]
products["description"] = products["description"].replace({None: np.nan})
products["num_votes"] = products["num_votes"].astype("Int64")
products.head()
# Out:
# /tmp/ipykernel_2754/156552489.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["description"] = products["description"].replace({None: np.nan})
# /tmp/ipykernel_2754/156552489.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products["num_votes"] = products["num_votes"].astype("Int64")
#    product_id                        created_at  \
# 0           1  2025-04-10T21:36:41.167902+02:00
# 1           2  2025-04-10T21:36:41.167902+02:00
# ...

# %%
categories = df[["category_id", "category_name"]].drop_duplicates()
categories
# Out:
#      category_id category_name
# 0              1         boots
# 514            2         balls

# %%
labels = df[["product_id", "labels"]]
labels["labels"].unique()

# labels = labels[labels["labels"] != "[]"]
# labels["labels"] = labels["labels"].apply(ast.literal_eval)

# labels = labels.explode("labels").dropna().rename(columns={"labels": "label"})
# labels.head()
# Out:
# array(['[]', "['Last Chance']", "['Sale']", "['New', 'Exclusive']",
#        "['New']", "['New', 'Last Chance']",
#        "['New', 'Last Chance', 'Exclusive']", "['Exclusive']",
#        "['Last Chance', 'Exclusive']", "['Sale', 'Last Chance']",
#        "['Sale', 'Exclusive']", "['Sale', 'Last Chance', 'Exclusive']"],
#       dtype=object)

# %%
related_products = df[["product_id", "related_products"]]
related_products["related_products"] = related_products["related_products"].apply(ast.literal_eval)
related_products = related_products.explode("related_products").dropna().rename(columns={"related_products": "related_product_id"})
related_products["related_product_id"] = related_products["related_product_id"].astype(int)
related_products.head(3)
# Out:
# /tmp/ipykernel_2754/801991093.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   related_products["related_products"] = related_products["related_products"].apply(ast.literal_eval)
#    product_id  related_product_id
# 0           1              199594
# 0           1              199576
# 0           1              199575

# %%
df.columns
# Out:
# Index(['product_id', 'created_at', 'title', 'price', 'old_price',
#        'description', 'avg_vote_rate', 'num_votes', 'labels',
#        'related_products', 'sizes.in_stock', 'sizes.out_of_stock',
#        'features.product_type', 'features.producer', 'features.collections',
#        'features.age', 'features.ground_type', 'features.type_of_class',
#        'features.upper', 'features.type_of_binding',
#        'features.boots_with_sock', 'features.collection', 'features.color',
#        'features.plays_in_these_boots', 'features.manufacturers_data',
#        'features.team', 'category_name', 'category_id', 'features.ball_size',
#        'features.connecting_type', 'features.weigh', 'features.league'],
#       dtype='object')

# %%
sizes = df[["product_id", "sizes.in_stock", "sizes.out_of_stock"]]

size_df = pd.DataFrame()
for col in sizes.columns[1:]:
    sizes[col] = sizes[col].apply(ast.literal_eval)

    explode = sizes[["product_id", col]].explode(col).dropna().rename(columns={col: "size"})
    explode["size"] = explode["size"].astype(str)
    explode["in_stock"] = True if col == "sizes.in_stock" else False

    size_df = pd.concat([x, explode], ignore_index=True)

size_df.head(3)
# Out:
# /tmp/ipykernel_2754/2027160316.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sizes[col] = sizes[col].apply(ast.literal_eval)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 11
#       8     explode["size"] = explode["size"].astype(str)
#       9     explode["in_stock"] = True if col == "sizes.in_stock" else False
# ---> 11     size_df = pd.concat([x, explode], ignore_index=True)
#      13 size_df.head(3)
#
# NameError: name 'x' is not defined

# %%
features_cols = [col for col in df.columns if "features." in col]
features = df[["product_id", *features_cols]]
features.head(1)
# Out:
#    product_id features.product_type features.producer features.collections  \
# 0           1        Football Boots            Adidas           Adidas F50
#
#   features.age features.ground_type features.type_of_class features.upper  \
# 0          Men     Firm Ground (Fg)           Professional      Synthetic
#
#   features.type_of_binding features.boots_with_sock  \
# 0                 Shoelace                       No
#
#          features.collection features.color features.plays_in_these_boots  \
# 0  Adidas Vivid Horizon Pack            Red                  Lionel Messi
#
#                        features.manufacturers_data features.team  \
# 0  Adidas, Hoogoorddreef 9A, Amsterdam 1101 Ba, Nl           NaN
#
#   features.ball_size features.connecting_type features.weigh features.league
# 0                NaN                      NaN            NaN             NaN

# %%
x = pd.melt(features, id_vars=["product_id"], value_vars=features_cols, var_name="feature", value_name="value").dropna()
x["feature"] = x["feature"].str.split(".").str[-1]
x["feature"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x = pd.melt(features, id_vars=["product_id"], value_vars=features_cols, var_name="feature", value_name="value").dropna()
#       2 x["feature"] = x["feature"].str.split(".").str[-1]
#       3 x["feature"].unique()
#
# NameError: name 'features' is not defined
