# %%
import pandas as pd
import numpy as np
from pathlib import Path
from slugify import slugify
import re

# %% [markdown]
# ### Import CSV files

# %%
# path to raw data direcotry
web_scraping_dir = Path.cwd().parent
raw_data_dir = web_scraping_dir / "data" / "raw_data"

# open csv files
products_df = pd.read_csv(raw_data_dir / "products.csv", delimiter=";", parse_dates=["created_at"])
colors_df = pd.read_csv(raw_data_dir / "colors.csv", delimiter=";")
sizes_df = pd.read_csv(raw_data_dir / "sizes.csv", delimiter=";")
labels_df = pd.read_csv(raw_data_dir / "labels.csv", delimiter=";")
categories_df = pd.read_csv(raw_data_dir / "categories.csv", delimiter=";", parse_dates=["created_at"])
boots_category_df = (
    pd.read_csv(raw_data_dir / "boots_category.csv", delimiter=";")
    .drop("Product Type:", axis=1)
)
balls_category_df = (
    pd.read_csv( raw_data_dir / "balls_category.csv", delimiter=";")
    .drop("Product Type:", axis=1)
)

# %%
# Create images table by getting scraped images names
img_dir = web_scraping_dir / "data" / "product_images"
paths = img_dir.rglob("*")
dir_name = "product_images"
images = []

for path in paths:
    if dir_name in path.parts and path.is_file():
        prefix, img = str(path).split("/")[-2:]
        product_id = int(img.split("-")[0])
        image_name = f"{prefix}/{img}"
        is_thumbnail = True if int(img.split("-")[1][0]) == 1 else False

        row = {
            "product_id": product_id,
            "image_name": image_name,
            "is_thumbnail": is_thumbnail,
        }
        images.append(row)

images_df = pd.DataFrame(images)

# %% [markdown]
# ### Helper functions

# %%
# Cleans text by removing HTML, quotes, and extra spaces.
def clean_description(data):
    data = re.sub(r"<.*?>", " ", data)
    data = re.sub(r'[,\'"]', "", data)
    data = re.sub(r"\s+", " ", data)
    return data.strip()[1:-1].strip()


# Formats column names: lowercase, underscores
def format_cols(df):
    col_names = {}
    for i, col in enumerate(df.columns):
        if i > 0:
            col_names[col] = col[:-1].lower().replace(" ", "_").replace("'", "")
        else:
            col_names[col] = col
    return col_names


# Strips and capitalizes specified string columns in a DataFrame.
def format_str(df, cols):
    for col in cols:
        df[col] = df[col].str.strip().str.title()

# %% [markdown]
# ### Data cleaning
#
# colors, sizes and categories are quite simple tables and don't require any transformation

# %%
# product table
products_df.drop_duplicates(inplace=True)
products_df["name"] = products_df["name"].str.split("\n", expand=True)[0]

products_df["price"] = products_df["price"].str.split("\n", expand=True)[1].str.strip().str[:-2].str.replace(",", ".").astype(float)
products_df["before_discount"] = (
    products_df["before_discount"]
    .str.split("\n", expand=True)[1]
    .str.strip()
    .str[:-2]
    .str.replace(",", ".")
    .astype(float)
)
products_df["sale_pct"] = round((
    products_df["before_discount"] - products_df["price"]
) / products_df["before_discount"] * 100)

products_df["description"] = products_df["description"].apply(clean_description)
products_df["slug"] = products_df["name"].apply(slugify)

previews = images_df.query("is_thumbnail == True")
products_df = (
    products_df.merge(previews, on="product_id", how="left")
    .drop(columns=["is_thumbnail"])
    .rename(columns={"image_name":"img_path"})
)

products_df.head(5)
# Out:
#    product_id  category_id                                               name  \
# 0           1            1              Cleats adidas F50 Elite LL FG - White
# 1           2            1  Cleats Nike Zoom Mercurial Vapor 16 Elite FG -...
# 2           3            1  Cleats Nike Zoom Mercurial Vapor 16 Elite FG -...
# 3           4            1                  adidas Mundial Team Boots - Black
# 4           5            1  Cleats Nike Zoom Mercurial Vapor 16 Elite FG -...
#
#     price  before_discount                                        description  \
# 0  270.00              NaN  Boost your pace in lightweight adidas F50 shoe...
# 1  194.99           269.99  Do you have an obsession with speed? The bigge...
# 2  182.99           269.99  Do you have an obsession with speed? The bigge...
# 3  107.99           150.00  This is probably one of the most popular shoe ...
# 4  269.99              NaN  Do you have an obsession with speed? The bigge...
#
#    scraped_num                                       scraped_link created_at  \
# 0       199578  https://www.r-gol.com/en/cleats-adidas-f50-eli... 2025-01-31
# 1       191711  https://www.r-gol.com/en/cleats-nike-zoom-merc... 2025-01-31
# 2       191710  https://www.r-gol.com/en/cleats-nike-zoom-merc... 2025-01-31
# 3        95634  https://www.r-gol.com/en/adidas-mundial-team-b... 2025-01-31
# 4       194479  https://www.r-gol.com/en/cleats-nike-zoom-merc... 2025-01-31
#
#    sale_pct                                               slug       img_path
# 0       NaN                cleats-adidas-f50-elite-ll-fg-white  boots/1-1.jpg
# 1      28.0  cleats-nike-zoom-mercurial-vapor-16-elite-fg-s...  boots/2-1.jpg
# 2      32.0  cleats-nike-zoom-mercurial-vapor-16-elite-fg-b...  boots/3-1.jpg
# 3      28.0                    adidas-mundial-team-boots-black  boots/4-1.jpg
# 4       NaN   cleats-nike-zoom-mercurial-vapor-16-elite-fg-red  boots/5-1.jpg

# %%
from pprint import pprint
# pprint(products_df)
x = products_df[:10].values.flatten().tolist()
pprint(x)
# Out:
# [1,
#  1,
#  'Cleats adidas F50 Elite LL FG - White',
#  270.0,
#  nan,
#  'Boost your pace in lightweight adidas F50 shoes designed for speed. These '
#  'laceless Elite football boots feature a thin Fibertouch upper with a '
#  'foot-hugging adidas PRIMEKNIT collar and 3D Sprintweb texture to keep the '
#  'ball close to your foot. The responsive Sprintframe 360 outsole designed for '
#  'playing on natural grass provides exceptional acceleration.',
#  199578,
#  'https://www.r-gol.com/en/cleats-adidas-f50-elite-ll-fg-white,p-199578',
#  Timestamp('2025-01-31 00:00:00'),
#  nan,
#  'cleats-adidas-f50-elite-ll-fg-white',
#  'boots/1-1.jpg',
#  2,
#  1,
#  'Cleats Nike Zoom Mercurial Vapor 16 Elite FG - sky blue',
#  194.99,
#  269.99,
#  'Do you have an obsession with speed? The biggest basketball stars have it '
#  'too. Thats why we created the Elite cleats with an improved 3/4 length Air '
#  'Zoom cushion. This model will provide you and the fastest players with the '
#  'acceleration you need to break through the defense line. As a result we have '
#  'created the most dynamic Mercurial shoes we have ever designed. All to '
#  'satisfy your pursuit of perfection. Exceptional ball feel Nike Gripknit is a '
#  'grippy material that provides better ball feel. It has a larger surface area '
#  'giving you more space to control the ball during high-speed dribbling or to '
#  'finish the game with an accurate shot on goal. In addition it conforms to '
#  'the shape of the foot and provides consistent grip in both wet and dry '
#  'conditions ensuring a snug fit comparable to track spikes. The embossed '
#  'microtexture works with Gripknit technology conforming to the foot and '
#  'allowing for even better ball feel. Dynamic grip The wavy tread pattern '
#  'created by the cascadingly placed cleats covers a larger surface area in the '
#  'Air Zoom cushion area and provides proper grip. The largest cleat has the '
#  'same height as traditional mid cleats so the grip is consistent everywhere. '
#  'In addition to the wavy tread we have also used studs in the shape of fir '
#  'trees and blades which make it easier to stop during dynamic turns. Perfect '
#  'fit The Flyknit upper is designed for speed. The Atomknit fabric an '
#  'extremely lightweight and durable version of Flyknit is placed on the sides '
#  'to reduce the weight of the shoes and provide support. By combining Gripknit '
#  'Atomknit and Flyknit technologies we have created the thinnest Mercurial '
#  'upper allowing for better ball feel and faster adaptation to the foot.',
#  191711,
#  'https://www.r-gol.com/en/cleats-nike-zoom-mercurial-vapor-16-elite-fg-sky-blue,p-191711',
#  Timestamp('2025-01-31 00:00:00'),
#  28.0,
#  'cleats-nike-zoom-mercurial-vapor-16-elite-fg-sky-blue',
#  'boots/2-1.jpg',
#  3,
#  1,
#  'Cleats Nike Zoom Mercurial Vapor 16 Elite FG - Black',
#  182.99,
#  269.99,
#  'Do you have an obsession with speed? The biggest basketball stars have it '
#  'too. Thats why we created the Elite cleats with an improved 3/4 length Air '
#  'Zoom cushion. This model will provide you and the fastest players with the '
#  'acceleration you need to break through the defense line. As a result we have '
#  'created the most dynamic Mercurial shoes we have ever designed. All to '
#  'satisfy your pursuit of perfection. Exceptional ball feel Nike Gripknit is a '
#  'grippy material that provides better ball feel. It has a larger surface area '
#  'giving you more space to control the ball during high-speed dribbling or to '
#  'finish the game with an accurate shot on goal. In addition it conforms to '
#  'the shape of the foot and provides consistent grip in both wet and dry '
#  'conditions ensuring a snug fit comparable to track spikes. The embossed '
#  'microtexture works with Gripknit technology conforming to the foot and '
#  'allowing for even better ball feel. Dynamic grip The wavy tread pattern '
#  'created by the cascadingly placed cleats covers a larger surface area in the '
#  'Air Zoom cushion area and provides proper grip. The largest cleat has the '
#  'same height as traditional mid cleats so the grip is consistent everywhere. '
#  'In addition to the wavy tread we have also used studs in the shape of fir '
#  'trees and blades which make it easier to stop during dynamic turns. Perfect '
#  'fit The Flyknit upper is designed for speed. The Atomknit fabric an '
#  'extremely lightweight and durable version of Flyknit is placed on the sides '
#  'to reduce the weight of the shoes and provide support. By combining Gripknit '
#  'Atomknit and Flyknit technologies we have created the thinnest Mercurial '
#  'upper allowing for better ball feel and faster adaptation to the foot.',
#  191710,
#  'https://www.r-gol.com/en/cleats-nike-zoom-mercurial-vapor-16-elite-fg-black,p-191710',
#  Timestamp('2025-01-31 00:00:00'),
#  32.0,
#  'cleats-nike-zoom-mercurial-vapor-16-elite-fg-black',
#  'boots/3-1.jpg',
#  4,
#  1,
#  'adidas Mundial Team Boots - Black',
#  107.99,
#  150.0,
#  'This is probably one of the most popular shoe models on Polish pitches! Both '
#  'amateur and more advanced players love them. They were created with the '
#  'thought of those footballers who compete on artificial turf in mind. What '
#  'makes adidas Mundial Team shoes stand out is their durability. But we cant '
#  'forget about the huge comfort that the kangaroo leather upper provides. Add '
#  'to that the sole that ensures fantastic traction on artificial surfaces and '
#  'we have the perfect model! Remember that the kangaroo leather upper will '
#  'break in after the first use so pay special attention to choosing the right '
#  'size! How to choose the right football shoes?',
#  95634,
#  'https://www.r-gol.com/en/adidas-mundial-team-boots-black,p-95634',
#  Timestamp('2025-01-31 00:00:00'),
#  28.0,
#  'adidas-mundial-team-boots-black',
#  'boots/4-1.jpg',
#  5,
#  1,
#  'Cleats Nike Zoom Mercurial Vapor 16 Elite FG - Red',
#  269.99,
#  nan,
#  'Do you have an obsession with speed? The biggest basketball stars have it '
#  'too. Thats why we created the Elite cleats with an improved 3/4 length Air '
#  'Zoom cushion. This model will provide you and the fastest players with the '
#  'acceleration you need to break through the defense line. As a result we have '
#  'created the most dynamic Mercurial shoes we have ever designed. All to '
#  'satisfy your pursuit of perfection. Exceptional ball feel Nike Gripknit is a '
#  'grippy material that provides better ball feel. It has a larger surface area '
#  'giving you more space to control the ball during high-speed dribbling or to '
#  'finish the game with an accurate shot on goal. In addition it conforms to '
#  'the shape of the foot and provides consistent grip in both wet and dry '
#  'conditions ensuring a snug fit comparable to track spikes. The embossed '
#  'microtexture works with Gripknit technology conforming to the foot and '
#  'allowing for even better ball feel. Dynamic grip The wavy tread pattern '
#  'created by the cascadingly placed cleats covers a larger surface area in the '
#  'Air Zoom cushion area and provides proper grip. The largest cleat has the '
#  'same height as traditional mid cleats so the grip is consistent everywhere. '
#  'In addition to the wavy tread we have also used studs in the shape of fir '
#  'trees and blades which make it easier to stop during dynamic turns. Perfect '
#  'fit The Flyknit upper is designed for speed. The Atomknit fabric an '
#  'extremely lightweight and durable version of Flyknit is placed on the sides '
#  'to reduce the weight of the shoes and provide support. By combining Gripknit '
#  'Atomknit and Flyknit technologies we have created the thinnest Mercurial '
#  'upper allowing for better ball feel and faster adaptation to the foot.',
#  194479,
#  'https://www.r-gol.com/en/cleats-nike-zoom-mercurial-vapor-16-elite-fg-red,p-194479',
#  Timestamp('2025-01-31 00:00:00'),
#  nan,
#  'cleats-nike-zoom-mercurial-vapor-16-elite-fg-red',
#  'boots/5-1.jpg',
#  6,
#  1,
#  'Cleats Nike Phantom Luna II Elite FG - Black',
#  159.99,
#  279.99,
#  'Step into a new day and show the world what youre made of. A bright '
#  'iridescent plate futuristic graphics and vibrant colors reminiscent of a '
#  'gradient sunrise evoke the powerful female game. This is a power that can '
#  'unite us on and off the pitch. Weve taken feedback from athletes to provide '
#  'the traction you need to play fast and confidently. Thats what football is '
#  'all about after all. The studs designed with craftsmanship in mind allow for '
#  'precise turns when the game picks up speed and give a national '
#  'flair.Traction on the pitchThe Nike Cyclone 360 pattern allows for quick and '
#  'agile movements that give you confidence to dynamically change direction and '
#  'feel secure when the game picks up speed.Better touchNike Gripknit is a '
#  'grippy material that provides better ball touch. It covers the first two '
#  'laces and the increased surface area improves ball control. Additionally it '
#  'conforms to the shape of your foot and provides consistent traction in both '
#  'wet and dry conditions. The embossed micro-texture works with the Gripknit '
#  'technology to conform to your foot and give you even better ball '
#  'touch.Proper fit and stabilityThe asymmetrical lacing allows for a larger '
#  'contact area when dribbling passing and scoring. The modified lacing pattern '
#  'increases the adjustability in the midfoot area making it easier to fit '
#  'those with a flatter or higher arch. The asymmetrical Flyknit collar '
#  'provides a snug fit. The subtle drawcords in the collars allow for better '
#  'ball contact with the ground around the ankle when receiving and passing.',
#  191682,
#  'https://www.r-gol.com/en/cleats-nike-phantom-luna-ii-elite-fg-black,p-191682',
#  Timestamp('2025-01-31 00:00:00'),
#  43.0,
#  'cleats-nike-phantom-luna-ii-elite-fg-black',
#  'boots/6-1.jpg',
#  7,
#  1,
#  'Cleats Nike Phantom GX Elite FG',
#  186.99,
#  266.99,
#  'Do you have an obsession with perfecting your craft? Elite Korki designed '
#  'for you and the worlds biggest stars stand out for their high quality '
#  'because you demand perfection from yourself and your footwear. Nike Gripknit '
#  'revolutionary material provides better ball feel. The silhouette was '
#  'designed to increase precision when striking and taking control of the ball. '
#  'Better ball contact Nike Gripknit is a grippy material that provides better '
#  'ball feel. It covers most of the upper including the first two rows of laces '
#  'thus being in the areas of most frequent contact with the ball. In addition '
#  'it adapts to the shape of the foot and provides uniform grip in both wet and '
#  'dry conditions. Fit and comfort Asymmetrical collar and heel areas provide '
#  'comfort. Soft elements in the heel area make it easier to break in the shoes '
#  'and reduce the risk of irritation and foot squeezing while providing the '
#  'necessary stability. Grip on the pitch Tri-star studs work with the flexible '
#  'grooves in the front of the shoe to provide optimal grip and make it easier '
#  'to make directional changes. See those lines on the outer sole? They fit '
#  'your dynamic playing style and zigzag movements allowing you to bypass '
#  'defenders and take a shot.',
#  191675,
#  'https://www.r-gol.com/en/cleats-nike-phantom-gx-elite-fg,p-191675',
#  Timestamp('2025-01-31 00:00:00'),
#  30.0,
#  'cleats-nike-phantom-gx-elite-fg',
#  'boots/7-1.jpg',
#  8,
#  1,
#  'Cleats adidas Predator Elite LL FG - Black',
#  270.0,
#  nan,
#  'Enter every match knowing that you will score points in adidas Predator '
#  'Elite shoes designed for goals. The flexible HybridTouch upper with '
#  'strategically placed Strikeskin rubber elements and a laced construction was '
#  'created to help you achieve perfect ball control. The Controlframe 2.0 '
#  'outsole for natural surfaces and the adidas PRIMEKNIT collar provide '
#  'stability as you give it your all.',
#  199543,
#  'https://www.r-gol.com/en/cleats-adidas-predator-elite-ll-fg-black,p-199543',
#  Timestamp('2025-01-31 00:00:00'),
#  nan,
#  'cleats-adidas-predator-elite-ll-fg-black',
#  'boots/8-1.jpg',
#  9,
#  1,
#  'Cleats adidas Predator Elite LL SG - Black',
#  270.0,
#  nan,
#  'Enter every match knowing that you will score points in adidas Predator '
#  'Elite shoes designed for goal scoring. The flexible HybridTouch upper with '
#  'strategically placed Strikeskin rubber elements and a laceless construction '
#  'was created to help you have perfect contact with the ball. The Controlframe '
#  '2.0 outsole for soft ground play and the adidas PRIMEKNIT collar provide '
#  'stability as you give it your all.',
#  199533,
#  'https://www.r-gol.com/en/cleats-adidas-predator-elite-ll-sg-black,p-199533',
#  Timestamp('2025-01-31 00:00:00'),
#  nan,
#  'cleats-adidas-predator-elite-ll-sg-black',
#  'boots/9-1.jpg',
#  10,
#  1,
#  'Cleats adidas Predator Elite FG - Black',
#  260.0,
#  nan,
#  'Enter every match knowing that you will score points in adidas Predator '
#  'Elite shoes designed for goals. The flexible HybridTouch upper with '
#  'strategically placed Strikeskin rubber elements in the forefoot was created '
#  'to help you have perfect contact with the ball. The Controlframe 2.0 outsole '
#  'for natural surfaces and the adidas PRIMEKNIT collar provide stability as '
#  'you give it your all.',
#  199546,
#  'https://www.r-gol.com/en/cleats-adidas-predator-elite-fg-black,p-199546',
#  Timestamp('2025-01-31 00:00:00'),
#  nan,
#  'cleats-adidas-predator-elite-fg-black',
#  'boots/10-1.jpg']

# %%
labels_df["label_name"] = labels_df["label_name"].str.strip()
sizes_df["in_stock"] = np.where(sizes_df["in_stock"] == 1, True, False)
categories_df["category_name"] = np.where(
    categories_df["category_name"] == "football_boots", "boots", "balls"
)

# %%
# football boots category
boots_cols = format_cols(boots_category_df)
boots_category_df.rename(columns=boots_cols, inplace=True)
boots_cols_old = ["producer", "collections", "collection", "class", "upper", "color", "type_of_binding", "manufacturers_data"]
format_str(boots_category_df, boots_cols_old)

boots_category_df.rename(
    columns={"class": "class_type", "collection": "collection_name"}, inplace=True
)
boots_category_df.head(5)
# Out:
#    product_id producer           collections age_group  \
# 0           1   Adidas            Adidas F50       Men
# 1           2     Nike  Nike Mercurial Vapor       Men
# 2           3     Nike  Nike Mercurial Vapor       Men
# 3           4   Adidas        Adidas Classic       Men
# 4           5     Nike  Nike Mercurial Vapor       Men
#
#                 ground_type    class_type      upper type_of_binding  \
# 0          Firm Ground (FG)  Professional  Synthetic            Lack
# 1          Firm Ground (FG)  Professional  Synthetic        Shoelace
# 2          Firm Ground (FG)  Professional  Synthetic        Shoelace
# 3  Artificial Grass (AG/TF)  Professional    Leather        Shoelace
# 4          Firm Ground (FG)  Professional  Synthetic        Shoelace
#
#   boots_with_sock         collection_name     color plays_in_these_boots  \
# 0              No     Adidas Pure Victory     White         Lionel Messi
# 1              No  Nike Mad Ambition Pack  Sky Blue   Robert Lewandowski
# 2              No   Nike Shadow Pack 2024     Black   Robert Lewandowski
# 3              No          Adidas Classic     Black                  NaN
# 4              No    Nike Mad Energy Pack       Red   Robert Lewandowski
#
#                                   manufacturers_data team
# 0  Adidas Ag, Adi-Dassler-Strasse 1, 91074 Herzog...  NaN
# 1  Nike Retail B.V., Po Box 6453, Colosseum 1, 12...  NaN
# 2  Nike Retail B.V., Po Box 6453, Colosseum 1, 12...  NaN
# 3  Adidas Ag, Adi-Dassler-Strasse 1, 91074 Herzog...  NaN
# 4  Nike Retail B.V., Po Box 6453, Colosseum 1, 12...  NaN

# %%
# football balls category
balls_cols = format_cols(balls_category_df)
balls_category_df.rename(columns=balls_cols, inplace=True)
balls_category_df["ball_size"] = (
    balls_category_df["ball_size"].replace("Futsal", 4).fillna(5).astype(int)
)
balls_cols_old = ["producer", "collection", "connecting_type", "manufacturers_data"]
format_str(balls_category_df, balls_cols_old)

balls_category_df.rename(
    columns={"weigh": "weight", "class": "class_type"}, inplace=True
)
balls_category_df.head(5)
# Out:
#    product_id producer  ball_size       ground_type class_type  \
# 0         453     Nike          5  Firm Ground (FG)      Match
# 1         454   Adidas          5  Firm Ground (FG)      Match
# 2         455   Select          4    Indoor (IC/IN)      Match
# 3         456   Adidas          5  Firm Ground (FG)      Match
# 4         457   Adidas          5  Firm Ground (FG)      Match
#
#           collection   connecting_type    weight              color  \
# 0              Other  Thermally Welded  410-450g             Yellow
# 1        Ekstraklasa               NaN  410-450g              White
# 2             Select  Thermally Welded  400-440g  White, Multicolor
# 3          Ucl 24/25  Thermally Welded  410-450g         Multicolor
# 4  Women'S Euro 2025  Thermally Welded  410-450g              White
#
#                                   manufacturers_data league team
# 0  Nike Retail B.V., Po Box 6453, Colosseum 1, 12...    NaN  NaN
# 1  Adidas Ag, Adi-Dassler-Strasse 1, 91074 Herzog...    NaN  NaN
# 2  Select Sport A/S, Fabriksparken 46, Dk 2600 Gl...    NaN  NaN
# 3  Adidas Ag, Adi-Dassler-Strasse 1, 91074 Herzog...    NaN  NaN
# 4  Adidas Ag, Adi-Dassler-Strasse 1, 91074 Herzog...    NaN  NaN

# %% [markdown]
# ### Export cleaned data

# %%
cleaned_data_dir = web_scraping_dir / "data" / "cleaned_data"

products_df.to_csv(cleaned_data_dir / "products.csv", index=False, sep=";")
colors_df.to_csv(cleaned_data_dir / "colors.csv", index=False, sep=";")
sizes_df.to_csv(cleaned_data_dir / "sizes.csv", index=False, sep=";")
labels_df.to_csv(cleaned_data_dir / "labels.csv", index=False, sep=";")
categories_df.to_csv(cleaned_data_dir / "categories.csv", index=False, sep=";")
boots_category_df.to_csv(cleaned_data_dir / "boots_category.csv", index=False, sep=";")
balls_category_df.to_csv(cleaned_data_dir / "balls_category.csv", index=False, sep=";")
images_df.to_csv(cleaned_data_dir / "images.csv", index=False, sep=";")
