# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
web_scraping_dir = Path.cwd()
raw_data_dir = web_scraping_dir / "data" / "raw_data"

products_df = pd.read_csv(raw_data_dir / "products.csv", delimiter=";")
colors_df = pd.read_csv(raw_data_dir / "colors.csv", delimiter=";")
sizes_df = pd.read_csv(raw_data_dir / "sizes.csv", delimiter=";")
categories_df = pd.read_csv(raw_data_dir / "categories.csv", delimiter=";")
boots_category_df = pd.read_csv(raw_data_dir / "boots_category.csv", delimiter=";")
balls_category_df = pd.read_csv(raw_data_dir / "balls_category.csv", delimiter=";")

# %%
products_df.head()
# Out:
#    id  scaped_id  category_id  \
# 0   1     199578            1
# 1   2     191711            1
# 2   3     191710            1
# 3   4      95634            1
# 4   5     194479            1
#
#                                                 name             price  \
# 0  Cleats adidas F50 Elite LL FG - White\n\t\t\t\...  \n    270,00 €\n
# 1  Cleats Nike Zoom Mercurial Vapor 16 Elite FG -...  \n    194,99 €\n
# 2  Cleats Nike Zoom Mercurial Vapor 16 Elite FG -...  \n    182,99 €\n
# 3  adidas Mundial Team Boots - Black\n\t\t\t\t\t\...  \n    107,99 €\n
# 4  Cleats Nike Zoom Mercurial Vapor 16 Elite FG -...  \n    269,99 €\n
#
#                                          description  \
# 0  [<p>Boost your pace in lightweight adidas F50 ...
# 1  ["Do you have an obsession with speed? The big...
# 2  ["Do you have an obsession with speed? The big...
# 3  ['This is probably one of the most popular sho...
# 4  ["Do you have an obsession with speed? The big...
#
# ...

# %%
colors_df.head()
# Out:
#    product_id  color_id
# 0           1    199579
# 1           1    190236
# 2           1    190228
# 3           1    190227
# 4           2    194479

# %%
sizes_df.head()
# Out:
#    product_id size_num  in_stock
# 0           1   39 1/3         1
# 1           1       40         1
# 2           1   40 2/3         1
# 3           1   41 1/3         1
# 4           1       42         1

# %%
categories_df.head()
# Out:
#    category_id   category_name
# 0            1  football_boots
# 1            2       footballs

# %%
boots_category_df.head()
# Out:
#    product_id   Product Type: Producer:          Collections: Age Group:  \
# 0           1  Football boots    adidas            adidas F50        Men
# 1           2  Football boots      Nike  Nike Mercurial Vapor        Men
# 2           3  Football boots      Nike  Nike Mercurial Vapor        Men
# 3           4  Football boots    adidas        adidas Classic        Men
# 4           5  Football boots      Nike  Nike Mercurial Vapor        Men
#
#                Ground type:        Class:     Upper: Type of binding:  \
# 0          Firm Ground (FG)  Professional  Synthetic             Lack
# 1          Firm Ground (FG)  Professional  Synthetic         Shoelace
# 2          Firm Ground (FG)  Professional  Synthetic         Shoelace
# 3  Artificial Grass (AG/TF)  Professional    Leather         Shoelace
# 4          Firm Ground (FG)  Professional  Synthetic         Shoelace
#
#   Boots with sock:             Collection:    Color: Plays in these boots:  \
# ...

# %%
balls_category_df.head()
# Out:
#    product_id Product Type: Producer: Ball size:      Ground type: Class:  \
# 0         452         Balls      Nike          5  Firm Ground (FG)  Match
# 1         453         Balls    adidas        NaN  Firm Ground (FG)  Match
# 2         454         Balls    Select          4    Indoor (IC/IN)  Match
# 3         455         Balls    adidas          5  Firm Ground (FG)  Match
# 4         456         Balls    adidas          5  Firm Ground (FG)  Match
#
#          Collection:  Connecting Type:    Weigh:             Color:  \
# 0              Other  Thermally welded  410-450g             Yellow
# 1        Ekstraklasa               NaN  410-450g              White
# 2             Select  Thermally welded  400-440g  White, Multicolor
# 3          UCL 24/25  Thermally welded  410-450g         Multicolor
# 4  Women's EURO 2025  Thermally welded  410-450g              White
#
#                                 Manufacturer's Data: League: Team:
# ...

# %%
# 1. construct a path for data > row_data
# 2. upload all tables
# 3. cleaning tables
#     - drop missing values
#     - drop duplicates
#     - convert to numeric values
#     - clean strings (strip, format)
# 4. load data to cleaned_data folder

# >> create a script to load images and datasets to google cloud
